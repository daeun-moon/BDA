# %% [markdown]
# # 로그스케일링
# - 왜도, 첨도 왼쪽으로 치우친 분포
# - 스케일링 작업을 할 때 로그함수를 이용하면 조금더 정규분포화가 잘 된다. 통상적으로 대부분 한쪽으로 치우쳐진 (왼쪽) 분포에 대해서는 로그스케일링
# - 로그함수를 이용해서 값을 스케일링한다고 보시면 됩니다.
# - 반대로 로그함수로 스케일링을 하면 정상값을 돌리려면 -> 지수함수를 사용한다.
# - 넘파이에서 제공되는 함수들 exp 지수함수 , 로그함수 log

# %%
from sklearn.datasets import load_iris
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#붓꽃 데이터 세트를 로딩하고 DataFrame으로 변환
iris = load_iris()
iris_data = iris.data
iris_df = pd.DataFrame(data=iris_data, columns = iris.feature_names)

# %%
iris_df.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)'],
#       dtype='object')

# %%
y= np.log(iris_df['sepal length (cm)']) # 로그변환
plt.plot(iris_df['sepal length (cm)'], label = 'Original')
plt.plot(y, label = 'log')
plt.suptitle('Log Transform', size =  24)
plt.legend()
plt.show()

# %%
# 결과해석 : 로그변환 후 변동 폭이 줄어들었다

# %%
y= np.log(iris_df['sepal width (cm)']) # 로그변환
plt.plot(iris_df['sepal width (cm)'], label = 'Original')
plt.plot(y, label = 'log')
plt.suptitle('Log Transform', size =  24)
plt.legend()
plt.show()

# %%
# 결과해석 : 로그변환 후 변동 폭이 줄어들었다

# %%
y= np.log(iris_df['petal length (cm)']) # 로그변환
plt.plot(iris_df['petal length (cm)'], label = 'Original')
plt.plot(y, label = 'log')
plt.suptitle('Log Transform', size =  24)
plt.legend()
plt.show()

# %%
# 결과해석 : 로그변환 후 변동 폭이 줄어들었다

# %%
y= np.log(iris_df['petal width (cm)']) # 로그변환
plt.plot(iris_df['petal width (cm)'], label = 'Original')
plt.plot(y, label = 'log')
plt.suptitle('Log Transform', size =  24)
plt.legend()
plt.show()

# %%
# 결과해석 : 로그변환 후 변동 폭이 커졌다. 이유는 0과 1사이의 값은 로그 변환을 취하게 되면 음수로 변하게 되고
#  1이상의 값들은 로그변환 후  양수로 변하게 되면서 폭이 더 커진 것이다.
