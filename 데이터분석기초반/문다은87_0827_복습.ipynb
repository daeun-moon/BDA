# %% [markdown]
# # 파일 불러오기

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df= pd.read_csv('salary_class.csv')
df=df[['age', 'workclass', 'education', 'education-num',
       'marital-status', 'occupation', 'relationship', 'race', 'sex',
       'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
       'class']]
df
# Out:
#        age     workclass     education  education-num      marital-status  \
# 0       25       Private          11th              7       Never-married
# 1       38       Private       HS-grad              9  Married-civ-spouse
# 2       28     Local-gov    Assoc-acdm             12  Married-civ-spouse
# 3       44       Private  Some-college             10  Married-civ-spouse
# 4       18           NaN  Some-college             10       Never-married
# ...    ...           ...           ...            ...                 ...
# 48837   27       Private    Assoc-acdm             12  Married-civ-spouse
# 48838   40       Private       HS-grad              9  Married-civ-spouse
# 48839   58       Private       HS-grad              9             Widowed
# 48840   22       Private       HS-grad              9       Never-married
# 48841   52  Self-emp-inc       HS-grad              9  Married-civ-spouse
#
#               occupation relationship   race     sex  capital-gain  \
# ...

# %% [markdown]
# # 기본 정보 확인

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             48842 non-null  int64
#  1   workclass       46043 non-null  object
#  2   education       48842 non-null  object
#  3   education-num   48842 non-null  int64
#  4   marital-status  48842 non-null  object
#  5   occupation      46033 non-null  object
#  6   relationship    48842 non-null  object
#  7   race            48842 non-null  object
#  8   sex             48842 non-null  object
#  9   capital-gain    48842 non-null  int64
#  10  capital-loss    48842 non-null  int64
#  11  hours-per-week  48842 non-null  int64
#  12  native-country  47985 non-null  object
#  13  class           48842 non-null  int64
# dtypes: int64(6), object(8)
# memory usage: 5.2+ MB

# %%
df.describe()
# Out:
#                 age  education-num  capital-gain  capital-loss  \
# count  48842.000000   48842.000000  48842.000000  48842.000000
# mean      38.643585      10.078089   1079.067626     87.502314
# std       13.710510       2.570973   7452.019058    403.004552
# min       17.000000       1.000000      0.000000      0.000000
# 25%       28.000000       9.000000      0.000000      0.000000
# 50%       37.000000      10.000000      0.000000      0.000000
# 75%       48.000000      12.000000      0.000000      0.000000
# max       90.000000      16.000000  99999.000000   4356.000000
#
#        hours-per-week         class
# count    48842.000000  48842.000000
# mean        40.422382      0.239282
# std         12.391444      0.426649
# min          1.000000      0.000000
# 25%         40.000000      0.000000
# 50%         40.000000      0.000000
# 75%         45.000000      0.000000
# max         99.000000      1.000000

# %%
df.describe(include='all') # 숫자형 변수가 아니더라도 보여줌. unique, top, freq 행 추가
# Out:
#                  age workclass education  education-num      marital-status  \
# count   48842.000000     46043     48842   48842.000000               48842
# unique           NaN         8        16            NaN                   7
# top              NaN   Private   HS-grad            NaN  Married-civ-spouse
# freq             NaN     33906     15784            NaN               22379
# mean       38.643585       NaN       NaN      10.078089                 NaN
# std        13.710510       NaN       NaN       2.570973                 NaN
# min        17.000000       NaN       NaN       1.000000                 NaN
# 25%        28.000000       NaN       NaN       9.000000                 NaN
# 50%        37.000000       NaN       NaN      10.000000                 NaN
# 75%        48.000000       NaN       NaN      12.000000                 NaN
# max        90.000000       NaN       NaN      16.000000                 NaN
#
# ...

# %% [markdown]
# # 범주형 변수

# %%
#인코딩해야하는 데이터만 확인해 보자 => 숫자형 변수가 아닌 것들만 확인해보자!
obj_list = []
for i in df.columns:
    if df[i].dtype=='object':
        obj_list.append(i)
df[obj_list]
# Out:
#           workclass     education      marital-status         occupation  \
# 0           Private          11th       Never-married  Machine-op-inspct
# 1           Private       HS-grad  Married-civ-spouse    Farming-fishing
# 2         Local-gov    Assoc-acdm  Married-civ-spouse    Protective-serv
# 3           Private  Some-college  Married-civ-spouse  Machine-op-inspct
# 4               NaN  Some-college       Never-married                NaN
# ...             ...           ...                 ...                ...
# 48837       Private    Assoc-acdm  Married-civ-spouse       Tech-support
# 48838       Private       HS-grad  Married-civ-spouse  Machine-op-inspct
# 48839       Private       HS-grad             Widowed       Adm-clerical
# 48840       Private       HS-grad       Never-married       Adm-clerical
# 48841  Self-emp-inc       HS-grad  Married-civ-spouse    Exec-managerial
#
#       relationship   race     sex native-country
# ...

# %%
df_obj= df[obj_list]

# %%
# 교윳값들에 대한 판단
df_obj['workclass'].value_counts()
# Out:
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: workclass, dtype: int64

# %%
df_obj['education'].value_counts()
# Out:
# HS-grad         15784
# Some-college    10878
# Bachelors        8025
# Masters          2657
# Assoc-voc        2061
# 11th             1812
# Assoc-acdm       1601
# 10th             1389
# 7th-8th           955
# Prof-school       834
# 9th               756
# 12th              657
# Doctorate         594
# 5th-6th           509
# 1st-4th           247
# Preschool          83
# Name: education, dtype: int64

# %%
df_obj['marital-status'].value_counts()
# Out:
# Married-civ-spouse       22379
# Never-married            16117
# Divorced                  6633
# Separated                 1530
# Widowed                   1518
# Married-spouse-absent      628
# Married-AF-spouse           37
# Name: marital-status, dtype: int64

# %%
df_obj['occupation'].value_counts()
# Out:
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# Transport-moving     2355
# Handlers-cleaners    2072
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: occupation, dtype: int64

# %%
df_obj['race'].value_counts()
# Out:
# White                 41762
# Black                  4685
# Asian-Pac-Islander     1519
# Amer-Indian-Eskimo      470
# Other                   406
# Name: race, dtype: int64

# %%
df_obj['native-country'].value_counts()
# Out:
# United-States                 43832
# Mexico                          951
# Philippines                     295
# Germany                         206
# Puerto-Rico                     184
# Canada                          182
# El-Salvador                     155
# India                           151
# Cuba                            138
# England                         127
# China                           122
# South                           115
# Jamaica                         106
# Italy                           105
# Dominican-Republic              103
# Japan                            92
# Guatemala                        88
# Poland                           87
# Vietnam                          86
# Columbia                         85
# Haiti                            75
# Portugal                         67
# Taiwan                           65
# Iran                             59
# Greece                           49
# Nicaragua                        49
# ...

# %% [markdown]
# # df_base

# %%
df_base= df[['age','education-num','sex','hours-per-week','native-country','race','class']]
df_base
# Out:
#        age  education-num     sex  hours-per-week native-country   race  class
# 0       25              7    Male              40  United-States  Black      0
# 1       38              9    Male              50  United-States  White      0
# 2       28             12    Male              40  United-States  White      1
# 3       44             10    Male              40  United-States  Black      1
# 4       18             10  Female              30  United-States  White      0
# ...    ...            ...     ...             ...            ...    ...    ...
# 48837   27             12  Female              38  United-States  White      0
# 48838   40              9    Male              40  United-States  White      1
# 48839   58              9  Female              40  United-States  White      0
# 48840   22              9    Male              20  United-States  White      0
# 48841   52              9  Female              40  United-States  White      1
#
# ...

# %%
df_base['native-country'].value_counts()
# Out:
# United-States                 43832
# Mexico                          951
# Philippines                     295
# Germany                         206
# Puerto-Rico                     184
# Canada                          182
# El-Salvador                     155
# India                           151
# Cuba                            138
# England                         127
# China                           122
# South                           115
# Jamaica                         106
# Italy                           105
# Dominican-Republic              103
# Japan                            92
# Guatemala                        88
# Poland                           87
# Vietnam                          86
# Columbia                         85
# Haiti                            75
# Portugal                         67
# Taiwan                           65
# Iran                             59
# Greece                           49
# Nicaragua                        49
# ...

# %% [markdown]
# 1. 데이터의 분포가 대부분 미국이니깐 미국과 미국이 아닌 것으로도 나눌 수 있고
# 2. 대륙별로도 묶을 수 있고
# 3. EU 화폐가치 사용여부에 따라서 나눌 수 있다

# %% [markdown]
# - y값과 관계를 꼭 살펴봐야한다.
# - 독일은 연봉이 높은 경우 대부분이 1이 많다.
# - 폴란드는 연봉이 낮은 경우가 대부분이다, 0이 많다
# - 클래스가 불균형한 것들이 같이 묶여지면 편향이 생긴다
# - 그냥 대륙별로 묶게 되변 위의 경우가 발생하게 되고, 모델링 성능 저하 발생 가능
# - class 에 대한 것이 근거로 확인해야한다!

# %%
## 이진 분류의 경우
df_base.groupby('native-country')['class'].mean().sort_values()
# 1이 연봉이 높은 것
# 0이 연봉이 낮은 것
# 평균이 높다는 것은 -> 연봉이 높다는 것
# class의 평균이 높은 국가들은 1에 대한 비중이 높다.
# Out:
# native-country
# Holand-Netherlands            0.000000
# Guatemala                     0.034091
# Outlying-US(Guam-USVI-etc)    0.043478
# Columbia                      0.047059
# Dominican-Republic            0.048544
# Mexico                        0.049422
# Nicaragua                     0.061224
# El-Salvador                   0.070968
# Trinadad&Tobago               0.074074
# Vietnam                       0.081395
# Laos                          0.086957
# Peru                          0.086957
# Honduras                      0.100000
# Puerto-Rico                   0.108696
# Haiti                         0.120000
# Ecuador                       0.133333
# Jamaica                       0.141509
# Scotland                      0.142857
# Thailand                      0.166667
# South                         0.173913
# Portugal                      0.179104
# Poland                        0.195402
# United-States                 0.243977
# ...

# %% [markdown]
# - class가 높은 국가끼리 묶어주면
# 1. class가 높은 애들은 어떤 특성이 있나? 2차 분석이 필요하다. -> 아 다른 변수들도 뭔가 건들 수 있겠다.
# 2. unique한 값도 생각을 해서 진행해야 한다.
# - 피처엔지니어링 개념으로 접근시에는 이 새로운 파생변수로 사용 할 수 있다

# %% [markdown]
# ### class 우리가 예측해야 할 정답에 대해서 근거 기준을 가지고 꼭 데이터를 전처리 해야 한다!

# %%
df_base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             48842 non-null  int64
#  1   education-num   48842 non-null  int64
#  2   sex             48842 non-null  object
#  3   hours-per-week  48842 non-null  int64
#  4   native-country  47985 non-null  object
#  5   race            48842 non-null  object
#  6   class           48842 non-null  int64
# dtypes: int64(4), object(3)
# memory usage: 2.6+ MB

# %%
df_base.dropna(inplace=True)
# Out:
# <ipython-input-17-3c1dfc79aac0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_base.dropna(inplace=True)

# %% [markdown]
# # 기본 베이스 라인 모델로 모델링을 해보자!

# %%
#기본 베이스 라인 모델을 모델링 해보자!
df_base=pd.get_dummies(df_base)

# %%
df_base= df_base*1

# %%
df_base.columns
# Out:
# Index(['age', 'education-num', 'hours-per-week', 'class', 'sex_Female',
#        'sex_Male', 'native-country_Cambodia', 'native-country_Canada',
#        'native-country_China', 'native-country_Columbia',
#        'native-country_Cuba', 'native-country_Dominican-Republic',
#        'native-country_Ecuador', 'native-country_El-Salvador',
#        'native-country_England', 'native-country_France',
#        'native-country_Germany', 'native-country_Greece',
#        'native-country_Guatemala', 'native-country_Haiti',
#        'native-country_Holand-Netherlands', 'native-country_Honduras',
#        'native-country_Hong', 'native-country_Hungary', 'native-country_India',
#        'native-country_Iran', 'native-country_Ireland', 'native-country_Italy',
#        'native-country_Jamaica', 'native-country_Japan', 'native-country_Laos',
#        'native-country_Mexico', 'native-country_Nicaragua',
#        'native-country_Outlying-US(Guam-USVI-etc)', 'native-country_Peru',
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df_base.drop('class',axis=1),df_base['class'], test_size=0.4, random_state=1)

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier()
model.fit(X_train, y_train)
pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, pred)
# Out:
# 0.7762321558820465

# %% [markdown]
# # 파생변수 만들어서 피처엔지니어링으로 변수를 최소화하고 진행해보자

# %%
df_base2= df[['age','education-num','sex','hours-per-week','native-country','race','class']]

# %%
df_base2.dropna(inplace=True)
# Out:
# <ipython-input-25-626100b900ab>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_base2.dropna(inplace=True)

# %%
df_base2
# Out:
#        age  education-num     sex  hours-per-week native-country   race  class
# 0       25              7    Male              40  United-States  Black      0
# 1       38              9    Male              50  United-States  White      0
# 2       28             12    Male              40  United-States  White      1
# 3       44             10    Male              40  United-States  Black      1
# 4       18             10  Female              30  United-States  White      0
# ...    ...            ...     ...             ...            ...    ...    ...
# 48837   27             12  Female              38  United-States  White      0
# 48838   40              9    Male              40  United-States  White      1
# 48839   58              9  Female              40  United-States  White      0
# 48840   22              9    Male              20  United-States  White      0
# 48841   52              9  Female              40  United-States  White      1
#
# ...

# %%
df_fn=df_base2.groupby('native-country')['class'].mean()

# %%
df_fn=df_fn.reset_index()

# %%
df_base2_final=df_base2.merge(df_fn, on='native-country',how='left')

# %%
df_base2f =df_base2_final[['age','education-num','sex','hours-per-week','class_x','class_y','race']]

# %%
df_base2f=df_base2f.rename(columns = {'class_x':'class', 'class_y':'native-country'})

# %%
df_base2f
# Out:
#        age  education-num     sex  hours-per-week  class  native-country  \
# 0       25              7    Male              40      0        0.243977
# 1       38              9    Male              50      0        0.243977
# 2       28             12    Male              40      1        0.243977
# 3       44             10    Male              40      1        0.243977
# 4       18             10  Female              30      0        0.243977
# ...    ...            ...     ...             ...    ...             ...
# 47980   27             12  Female              38      0        0.243977
# 47981   40              9    Male              40      1        0.243977
# 47982   58              9  Female              40      0        0.243977
# 47983   22              9    Male              20      0        0.243977
# 47984   52              9  Female              40      1        0.243977
#
#         race
# 0      Black
# 1      White
# 2      White
# 3      Black
# 4      White
# ...

# %%
df_base2f=pd.get_dummies(df_base2f)

# %%
df_base2f=df_base2f*1

# %%
df_base2f
# Out:
#        age  education-num  hours-per-week  class  native-country  sex_Female  \
# 0       25              7              40      0        0.243977           0
# 1       38              9              50      0        0.243977           0
# 2       28             12              40      1        0.243977           0
# 3       44             10              40      1        0.243977           0
# 4       18             10              30      0        0.243977           1
# ...    ...            ...             ...    ...             ...         ...
# 47980   27             12              38      0        0.243977           1
# 47981   40              9              40      1        0.243977           0
# 47982   58              9              40      0        0.243977           1
# 47983   22              9              20      0        0.243977           0
# 47984   52              9              40      1        0.243977           1
#
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df_base2f.drop('class',axis=1),df_base2f['class'], test_size=0.4, random_state=1)

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier()
model.fit(X_train, y_train)
pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, pred)
# Out:
# 0.7745128686047723

# %% [markdown]
# - 인코딩을 그냥 바로 진행한 경우 0.7820152130874232
# - 엔지니어링을 한 경우 0.781702615400646

# %% [markdown]
# # 정확도를 높이려면?
# - 더 많은 데이터 학습
# - 하이퍼파라미터 튜닝
# - 다른 모델 사용

# %% [markdown]
# ###  새로운 데이터를 추가해 정확도를 높여보자!
# - race 인종에 대한 데이터를 추가해 보자!
# - 기본 베이스 라인 모델 정확도 : 0.776023757424195
# - 피처엔지니어링에 + race 변수 추가 : 0.7752422632072523

# %% [markdown]
# - 변수를 단순하게 추가하여 인코딩하는 것이 정확도를 높이는 것에 대해서는 오히려 반대의 결과를 줄 수 있다.
# - 데이터가 race가 없는 경우가 더 높은 정확도를 보였다.
# - 단순하게 바라보는 게 아니라 Class 에 대한 영향도, 실제 데이터를 추가 햇을 때 모델의 성능, 컬럼과의 관계 등을 살펴보고
# - 이런 것들으 다 종합적으로 판단한 후에 성능을 높여야 한다.

# %% [markdown]
# -------------

# %% [markdown]
# # 8/27 수업 코드 시작 - 전처리 이어서!

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'education', 'education-num', 'marital-status',
#        'occupation', 'relationship', 'race', 'sex', 'capital-gain',
#        'capital-loss', 'hours-per-week', 'native-country', 'class'],
#       dtype='object')

# %%
# 범주형 변수 싹 다 더미형 변수로 생성하기
df_add1=pd.get_dummies(df, drop_first=True)
df_add1=df_add1*1
df_add1
# Out:
#        age  education-num  capital-gain  capital-loss  hours-per-week  class  \
# 0       25              7             0             0              40      0
# 1       38              9             0             0              50      0
# 2       28             12             0             0              40      1
# 3       44             10          7688             0              40      1
# 4       18             10             0             0              30      0
# ...    ...            ...           ...           ...             ...    ...
# 48837   27             12             0             0              38      0
# 48838   40              9             0             0              40      1
# 48839   58              9             0             0              40      0
# 48840   22              9             0             0              20      0
# 48841   52              9         15024             0              40      1
#
# ...

# %%
# 정확도 체크
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df_add1.drop('class',axis=1),df_add1['class'], test_size=0.4, random_state=1)

from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
train_pred = model.predict(X_train)
test_pred = model.predict(X_test)

from sklearn.metrics import accuracy_score
print('train',accuracy_score(y_train, train_pred))
print('test',accuracy_score(y_test, test_pred))
# Out:
# train 0.9778536085992151
# test 0.8156318779751242

# %% [markdown]
# - 기본적으로 전의 base보다는 높게 나왔다
# - 근데 train >> test는 오버피팅! 과대적합
# - 과적합을 피하기는 어렵다.
# - 과적합은 없다는 게 아니라 train, validation, test의 값을 보면서 과적합 되기 전에 멈추는 것

# %% [markdown]
# ### 정확도를 좀 더 올리기 위해서는?
# - 피처를 추가하는 경우도 있다. ( 데이터를 추가 하는 것 )
# - 피처 엔지니어링을 통해 더 특성을 잘 뽑아낸다.
# - 하이퍼파라미터를 튜닝하여 진행한다.
# - 새로운 모델을 사용해 본다!

# %%
# 하이퍼파라미터를 추가해 보자!
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(max_depth=5)  #max_depth 새롭게 설정
model.fit(X_train, y_train)
train_pred = model.predict(X_train)
test_pred = model.predict(X_test)

from sklearn.metrics import accuracy_score
print('train',accuracy_score(y_train, train_pred))
print('test',accuracy_score(y_test, test_pred))
# Out:
# train 0.8516976625149292
# test 0.852126733889543

# %% [markdown]
# - test > train
# - 과소적합 모델의 단순화 개념

# %%
# 하이퍼파라미터를 추가해 보자!
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(max_depth=10) # 새로운 하이퍼파라미터
model.fit(X_train, y_train)
train_pred = model.predict(X_train)
test_pred = model.predict(X_test)

from sklearn.metrics import accuracy_score
print('train',accuracy_score(y_train, train_pred))
print('test',accuracy_score(y_test, test_pred))
# Out:
# train 0.8717283739976114
# test 0.861698316015765

# %%
# 다른 모델을 사용해보자~
from sklearn.ensemble import RandomForestClassifier
#랜덤포레스트

rf = RandomForestClassifier(random_state=111)
rf.fit(X_train, y_train)

train_pred = rf.predict(X_train)
test_pred = rf.predict(X_test)

print('train',accuracy_score(y_train, train_pred))
print('test',accuracy_score(y_test, test_pred))
# Out:
# train 0.9777853608599215
# test 0.8448584736653529

# %% [markdown]
# - 방금 위에서 사용한 모델을 랜덤포레스트 모델
# - 랜덤포레스트 값은 왜 더 test가 높은가?
# - 모델의 작동원리 때문에 이런 경우 발생!
# - ensemble의 작동원리 -> 랜덤포레스트는 부트스트래핑 방식으로 진행

# %%
from sklearn.ensemble import RandomForestClassifier
#랜덤포레스트

rf = RandomForestClassifier(max_depth=10,random_state=111,n_estimators =300) #n_estimators 디폴트는 100 데이터 샘플 개수 조정
rf.fit(X_train, y_train)

train_pred = rf.predict(X_train)
test_pred = rf.predict(X_test)

print('train',accuracy_score(y_train, train_pred))
print('test',accuracy_score(y_test, test_pred))
# Out:
# train 0.864289370414605
# test 0.8586784050775452

# %%
from sklearn.ensemble import RandomForestClassifier
#랜덤포레스트

rf = RandomForestClassifier(max_depth=10,random_state=111,n_estimators =500) #n_estimators 디폴트는 100 데이터 샘플 개수 조정
rf.fit(X_train, y_train)

train_pred = rf.predict(X_train)
test_pred = rf.predict(X_test)

print('train',accuracy_score(y_train, train_pred))
print('test',accuracy_score(y_test, test_pred))
# Out:
# train 0.8642552465449582
# test 0.8588831448021702

# %% [markdown]
# - DecisionTree, Randomforest
# - 가지치기를 하는 방식 : Information gain이 높은 쪽으로 가지 치는 형식
# - 데분기 67명을 분류해보자!
# ex) 성별 7:3, 안경유무, 5:5
# - 어떤 칼럼이 더 잘 분류하는 걸까?
# - 지니계수, 엔트로피 지수를 가지고 수치로 정량화해서 판단하는 것!

# %% [markdown]
# --------

# %% [markdown]
# # 자전거 수요 예측 데이터
# - datetime - hourly date + timestamp
# - season -  1 = spring, 2 = summer, 3 = fall, 4 = winter
# - holiday - whether the day is considered a holiday
# - workingday - whether the day is neither a weekend nor holiday
# - weather
#     - -1: Clear, Few clouds, Partly cloudy, Partly cloudy
#     - -2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist
#     - -3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered clouds
#     - -4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog
# - temp - temperature in Celsius
# - atemp - "feels like" temperature in Celsius
# - humidity - relative humidity
# - windspeed - wind speed
# - casual - number of non-registered user rentals initiated
# - registered - number of registered user rentals initiated
# - count - number of total rentals

# %%
train = pd.read_csv('train_bk.csv')
train
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 0      2011-01-01 00:00:00       1        0           0        1   9.84
# 1      2011-01-01 01:00:00       1        0           0        1   9.02
# 2      2011-01-01 02:00:00       1        0           0        1   9.02
# 3      2011-01-01 03:00:00       1        0           0        1   9.84
# 4      2011-01-01 04:00:00       1        0           0        1   9.84
# ...                    ...     ...      ...         ...      ...    ...
# 10881  2012-12-19 19:00:00       4        0           1        1  15.58
# 10882  2012-12-19 20:00:00       4        0           1        1  14.76
# 10883  2012-12-19 21:00:00       4        0           1        1  13.94
# 10884  2012-12-19 22:00:00       4        0           1        1  13.94
# 10885  2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  object
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.7+ KB

# %%
# 기존의 datetime 칼럼에서 date, year, month, day, hour, minute, second 칼럼 새롭게 생성
train['date'] = train['datetime'].apply(lambda x:x.split()[0])
train['year'] = train['datetime'].apply(lambda x:x.split('-')[0])
train['month'] = train['datetime'].apply(lambda x:x.split()[0].split('-')[1])
train['day'] = train['datetime'].apply(lambda x:x.split()[0].split('-')[2])


train['hour'] = train['datetime'].apply(lambda x:x.split()[1].split(':')[0])
train['minute'] = train['datetime'].apply(lambda x:x.split()[1].split(':')[1])
train['second'] = train['datetime'].apply(lambda x:x.split()[1].split(':')[2])

# %%
#요일도 생성 가능
from datetime import datetime
import calendar
print(datetime.strptime(train['date'][10], '%Y-%m-%d'))
#월화수목금토일 정수로 변환
print(datetime.strptime(train['date'][10], '%Y-%m-%d').weekday())
print(calendar.day_name[datetime.strptime(train['date'][10], '%Y-%m-%d').weekday()])
train['weekday'] = train['date'].apply(lambda dateString:calendar.day_name[datetime.strptime(dateString,'%Y-%m-%d').weekday()])
# Out:
# 2011-01-01 00:00:00
# 5
# Saturday

# %%
train.head(30)
# Out:
#                datetime  season  holiday  workingday  weather   temp   atemp  \
# 0   2011-01-01 00:00:00       1        0           0        1   9.84  14.395
# 1   2011-01-01 01:00:00       1        0           0        1   9.02  13.635
# 2   2011-01-01 02:00:00       1        0           0        1   9.02  13.635
# 3   2011-01-01 03:00:00       1        0           0        1   9.84  14.395
# 4   2011-01-01 04:00:00       1        0           0        1   9.84  14.395
# 5   2011-01-01 05:00:00       1        0           0        2   9.84  12.880
# 6   2011-01-01 06:00:00       1        0           0        1   9.02  13.635
# 7   2011-01-01 07:00:00       1        0           0        1   8.20  12.880
# 8   2011-01-01 08:00:00       1        0           0        1   9.84  14.395
# 9   2011-01-01 09:00:00       1        0           0        1  13.12  17.425
# 10  2011-01-01 10:00:00       1        0           0        1  15.58  19.695
# ...

# %%
# 수요예측에 대해서 모델링을 진행하게 되면 월별지수, 요일지수, 시간의 지수가 영향을 줄 수 있다.
# 예측해야할 count 분포
import seaborn as sns
sns.distplot(train['count'])
# Out:
# <ipython-input-57-a75e80574e79>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(train['count'])
# <Axes: xlabel='count', ylabel='Density'>

# %%
sns.distplot(np.log(train['count']))
# Out:
# <ipython-input-58-f9aefd84fb68>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(train['count']))
# <Axes: xlabel='count', ylabel='Density'>
