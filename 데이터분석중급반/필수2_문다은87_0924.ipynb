# %% [markdown]
# # 필수과제2
# -혼동 행렬의 TP, FP TN FN 값을 수치로 적어서 수기로 계산해 보시면 됩니다.
# 혼동 행렬의 TP, FP, TN, FN 값을 수기로 적어서 평가 지표를 계산하고 지금까지 배운 지표에 대해서 원리를 이해하기

# %% [markdown]
# ![KakaoTalk_20230928_005548913_02.jpg](data:image/jpeg;base64,...)
